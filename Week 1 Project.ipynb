# %% [markdown]
# IMPORTING LIBRARIES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# DATASET LOADING

# %%
data = pd.read_csv(r"C:\Users\Asus\Downloads\Delhi_AQI_Dataset.csv")

# %% [markdown]
# # Explore the dataset

# %%
data.head() # First 5 rows
# Out:
#     City      Date  AQI  PM2.5    PM10     NO2     SO2    CO     O3  \
# 0  Delhi  01/01/18  406  223.3  438.48  336.98  462.84  4.26  385.7
# 1  Delhi  02/01/18  418  229.9  451.44  346.94  476.52  4.39  397.1
# 2  Delhi  03/01/18  382  210.1  412.56  317.06  435.48  4.01  362.9
# 3  Delhi  04/01/18  366  201.3  395.28  303.78  417.24  3.84  347.7
# 4  Delhi  05/01/18  390  214.5  421.20  323.70  444.60  4.10  370.5
#
#    Unnamed: 9  Unnamed: 10
# 0         NaN          NaN
# 1         NaN          NaN
# 2         NaN          NaN
# 3         NaN          NaN
# 4         NaN          NaN

# %%
data.shape
# Out:
# (2191, 11)

# %%
print(data.columns)
# Out:
# Index(['City', 'Date', 'AQI', 'PM2.5', 'PM10', 'NO2', 'SO2', 'CO', 'O3',
#        'Unnamed: 9', 'Unnamed: 10'],
#       dtype='object')

# %% [markdown]
#  # Remove useless columns

# %%
data = data.drop(columns=["Unnamed: 9", "Unnamed: 10"], errors="ignore") 
data
# Out:
#        City      Date  AQI   PM2.5    PM10     NO2     SO2    CO      O3
# 0     Delhi  01/01/18  406  223.30  438.48  336.98  462.84  4.26  385.70
# 1     Delhi  02/01/18  418  229.90  451.44  346.94  476.52  4.39  397.10
# 2     Delhi  03/01/18  382  210.10  412.56  317.06  435.48  4.01  362.90
# 3     Delhi  04/01/18  366  201.30  395.28  303.78  417.24  3.84  347.70
# 4     Delhi  05/01/18  390  214.50  421.20  323.70  444.60  4.10  370.50
# ...     ...       ...  ...     ...     ...     ...     ...   ...     ...
# 2186  Delhi  27/12/24  353  194.15  381.24  292.99  402.42  3.71  335.35
# 2187  Delhi  28/12/24  139   76.45  150.12  115.37  158.46  1.46  132.05
# 2188  Delhi  29/12/24  225  123.75  243.00  186.75  256.50  2.36  213.75
# 2189  Delhi  30/12/24  173   95.15  186.84  143.59  197.22  1.82  164.35
# 2190  Delhi  31/12/24  283  155.65  305.64  234.89  322.62  2.97  268.85
#
# [2191 rows x 9 columns]

# %% [markdown]
# # Handle categorical/constant columns

# %%
if "City" in data.columns and data["City"].nunique() == 1:
    data = data.drop(columns=["City"])

# %% [markdown]
# # Convert Date column

# %%
data["Date"] = pd.to_datetime(data["Date"], errors="coerce")
data
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_16344\4278011918.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data["Date"] = pd.to_datetime(data["Date"], errors="coerce")
#            Date  AQI   PM2.5    PM10     NO2     SO2    CO      O3
# 0    2018-01-01  406  223.30  438.48  336.98  462.84  4.26  385.70
# 1    2018-02-01  418  229.90  451.44  346.94  476.52  4.39  397.10
# 2    2018-03-01  382  210.10  412.56  317.06  435.48  4.01  362.90
# 3    2018-04-01  366  201.30  395.28  303.78  417.24  3.84  347.70
# 4    2018-05-01  390  214.50  421.20  323.70  444.60  4.10  370.50
# ...         ...  ...     ...     ...     ...     ...   ...     ...
# 2186 2024-12-27  353  194.15  381.24  292.99  402.42  3.71  335.35
# 2187 2024-12-28  139   76.45  150.12  115.37  158.46  1.46  132.05
# 2188 2024-12-29  225  123.75  243.00  186.75  256.50  2.36  213.75
# 2189 2024-12-30  173   95.15  186.84  143.59  197.22  1.82  164.35
# 2190 2024-12-31  283  155.65  305.64  234.89  322.62  2.97  268.85
#
# [2191 rows x 8 columns]

# %%
data["Year"] = data["Date"].dt.year
data["Month"] = data["Date"].dt.month
data["Day"] = data["Date"].dt.day

# %%
data
# Out:
#            Date  AQI   PM2.5    PM10     NO2     SO2    CO      O3  Year  \
# 0    2018-01-01  406  223.30  438.48  336.98  462.84  4.26  385.70  2018
# 1    2018-02-01  418  229.90  451.44  346.94  476.52  4.39  397.10  2018
# 2    2018-03-01  382  210.10  412.56  317.06  435.48  4.01  362.90  2018
# 3    2018-04-01  366  201.30  395.28  303.78  417.24  3.84  347.70  2018
# 4    2018-05-01  390  214.50  421.20  323.70  444.60  4.10  370.50  2018
# ...         ...  ...     ...     ...     ...     ...   ...     ...   ...
# 2186 2024-12-27  353  194.15  381.24  292.99  402.42  3.71  335.35  2024
# 2187 2024-12-28  139   76.45  150.12  115.37  158.46  1.46  132.05  2024
# 2188 2024-12-29  225  123.75  243.00  186.75  256.50  2.36  213.75  2024
# 2189 2024-12-30  173   95.15  186.84  143.59  197.22  1.82  164.35  2024
# 2190 2024-12-31  283  155.65  305.64  234.89  322.62  2.97  268.85  2024
#
#       Month  Day
# 0         1    1
# 1         2    1
# 2         3    1
# 3         4    1
# 4         5    1
# ...     ...  ...
# 2186     12   27
# 2187     12   28
# 2188     12   29
# 2189     12   30
# 2190     12   31
#
# [2191 rows x 11 columns]

# %% [markdown]
# # Handle missing values

# %%
data.isnull().sum()
# Out:
# Date     0
# AQI      0
# PM2.5    0
# PM10     0
# NO2      0
# SO2      0
# CO       0
# O3       0
# Year     0
# Month    0
# Day      0
# dtype: int64

# %% [markdown]
# # Remove duplicates

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Feature Scaling (Normalization)

# %%
numeric_cols = data.select_dtypes(include=np.number).columns

# %%
numeric_cols
# Out:
# Index(['AQI', 'PM2.5', 'PM10', 'NO2', 'SO2', 'CO', 'O3', 'Year', 'Month',
#        'Day'],
#       dtype='object')

# %%
scaler = StandardScaler()

# %%
data[numeric_cols] = scaler.fit_transform(data[numeric_cols])
data
# Out:
#            Date       AQI     PM2.5      PM10       NO2       SO2        CO  \
# 0    2018-01-01  1.854899  1.854899  1.854899  1.854899  1.854899  1.851877
# 1    2018-02-01  1.967480  1.967480  1.967480  1.967480  1.967480  1.968027
# 2    2018-03-01  1.629738  1.629738  1.629738  1.629738  1.629738  1.628511
# 3    2018-04-01  1.479630  1.479630  1.479630  1.479630  1.479630  1.476622
# 4    2018-05-01  1.704792  1.704792  1.704792  1.704792  1.704792  1.708923
# ...         ...       ...       ...       ...       ...       ...       ...
# 2186 2024-12-27  1.357668  1.357668  1.357668  1.357668  1.357668  1.360472
# 2187 2024-12-28 -0.650019 -0.650019 -0.650019 -0.650019 -0.650019 -0.649823
# 2188 2024-12-29  0.156809  0.156809  0.156809  0.156809  0.156809  0.154295
# 2189 2024-12-30 -0.331041 -0.331041 -0.331041 -0.331041 -0.331041 -0.328176
# 2190 2024-12-31  0.700948  0.700948  0.700948  0.700948  0.700948  0.699308
#
#             O3      Year     Month       Day
# 0     1.854899 -1.340092 -1.601882 -1.673704
# 1     1.967480 -1.340092 -1.311894 -1.673704
# 2     1.629738 -1.340092 -1.021906 -1.673704
# 3     1.479630 -1.340092 -0.731918 -1.673704
# 4     1.704792 -1.340092 -0.441930 -1.673704
# ...        ...       ...       ...       ...
# 2186  1.357668  1.496303  1.587985  1.281240
# 2187 -0.650019  1.496303  1.587985  1.394892
# 2188  0.156809  1.496303  1.587985  1.508544
# 2189 -0.331041  1.496303  1.587985  1.622195
# 2190  0.700948  1.496303  1.587985  1.735847
#
# [2191 rows x 11 columns]

# %%
print(data.head())
# Out:
#         Date       AQI     PM2.5      PM10       NO2       SO2        CO  \
# 0 2018-01-01  1.854899  1.854899  1.854899  1.854899  1.854899  1.851877
# 1 2018-02-01  1.967480  1.967480  1.967480  1.967480  1.967480  1.968027
# 2 2018-03-01  1.629738  1.629738  1.629738  1.629738  1.629738  1.628511
# 3 2018-04-01  1.479630  1.479630  1.479630  1.479630  1.479630  1.476622
# 4 2018-05-01  1.704792  1.704792  1.704792  1.704792  1.704792  1.708923
#
#          O3      Year     Month       Day
# 0  1.854899 -1.340092 -1.601882 -1.673704
# 1  1.967480 -1.340092 -1.311894 -1.673704
# 2  1.629738 -1.340092 -1.021906 -1.673704
# 3  1.479630 -1.340092 -0.731918 -1.673704
# 4  1.704792 -1.340092 -0.441930 -1.673704

# %%
print("Final dataset shape:", data.shape)
# Out:
# Final dataset shape: (2191, 11)
